# %%
aws_keys_df = spark.read.format('csv')\
                        .option('inferschema','true')\
                        .option('header','true')\
                        .load('/Workspace/Users/leonardo.taguchi@aluno.faculdadeimpacta.com.br/pdd-analytics-etl/aws_keys/aws_keys.csv')
                        
aws_keys_df.columns

# %%
USER_NAME = aws_keys_df.select('USER_NAME').take(1)[0]['USER_NAME']
PASSWORD = aws_keys_df.select('PASSWORD').take(1)[0]['PASSWORD']
HOST = aws_keys_df.select('HOST').take(1)[0]['HOST']

DATABASE_NAME = 'postgres'
